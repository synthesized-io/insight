# %%
import os
if not 'workbookDir' in globals():
    workbookDir = os.getcwd()
os.chdir(os.path.split(workbookDir)[0])

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# # Synthetic data generation

# %%
import warnings
warnings.filterwarnings(action='ignore', message="numpy.dtype size changed")

# %%
import pandas as pd

# %% [markdown]
# ## Load transactions

# %%
data = pd.read_csv('data/uci/wine_quality.csv')
data.head(10)
# Out:
#   variant  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   white            7.0              0.27         0.36            20.7
# 1   white            6.3              0.30         0.34             1.6
# 2   white            8.1              0.28         0.40             6.9
# 3   white            7.2              0.23         0.32             8.5
# 4   white            7.2              0.23         0.32             8.5
# 5   white            8.1              0.28         0.40             6.9
# 6   white            6.2              0.32         0.16             7.0
# 7   white            7.0              0.27         0.36            20.7
# 8   white            6.3              0.30         0.34             1.6
# 9   white            8.1              0.22         0.43             1.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
# 5      0.050                 30.0                  97.0   0.9951  3.26
# 6      0.045                 30.0                 136.0   0.9949  3.18
# 7      0.045                 45.0                 170.0   1.0010  3.00
# 8      0.049                 14.0                 132.0   0.9940  3.30
# 9      0.044                 28.0                 129.0   0.9938  3.22
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 4       0.40      9.9        6
# 5       0.44     10.1        6
# 6       0.47      9.6        6
# 7       0.45      8.8        6
# 8       0.49      9.5        6
# 9       0.45     11.0        6

# %%
from sklearn.model_selection import train_test_split

# %%
data, test = train_test_split(data, test_size=0.2, random_state=42)

# %% [markdown]
# ## Train model and synthesize data

# %%
from synthesized.core import BasicSynthesizer

# %%
with BasicSynthesizer(data=data) as synthesizer:
    synthesizer.learn(data=data, verbose=5000)
    synthesized = synthesizer.synthesize(n=10000)
# Out:
# value types:
# variant categorical
# fixed acidity continuous
# volatile acidity continuous
# citric acid continuous
# residual sugar continuous
# chlorides continuous
# free sulfur dioxide continuous
# total sulfur dioxide continuous
# density continuous
# pH continuous
# sulphates continuous
# alcohol continuous
# quality categorical
# 5000: 2.88e+01
# 10000: 2.33e+01
# 15000: 7.74e+00
# 20000: 1.09e+01
# 25000: 7.15e+00
# 30000: 1.41e+01
# 35000: 6.13e+00
# 40000: 6.88e+00
# 45000: 5.57e+00
# 50000: 1.04e+01

# %% [markdown]
# ## Display synthesized data

# %%
synthesized.head(5)
# Out:
#   variant  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   white       6.131902          0.357285     0.245520        9.412804
# 1   white       6.632574          0.322376     0.269112        2.145477
# 2     red       8.453897          0.788028     0.286790        0.814323
# 3     red       9.316494          0.249532     0.512570       14.526936
# 4   white      10.215268          0.402310     0.416591        5.405608
#
#    chlorides  free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0   0.028919            36.108376             88.823776  0.992992  3.247849
# 1   0.033598            24.148859             79.475075  0.992615  3.657509
# 2   0.074577            28.221790             67.979980  0.995244  3.115869
# 3   0.142501            54.494984             91.333061  1.008100  3.164251
# 4   0.025208            22.376127             79.588020  0.992327  3.146396
#
#    sulphates    alcohol quality
# 0   0.439185  12.335223       6
# 1   0.576997  12.643697       7
# 2   0.760806  12.660710       5
# 3   0.760081   5.949756       7
# 4   0.372965  13.810005       4

# %%
data.head(5)
# Out:
#      variant  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 1916   white            6.6              0.25         0.36             8.1
# 947    white            8.5              0.16         0.35             1.6
# 877    white            6.0              0.28         0.34             1.6
# 2927   white            7.0              0.31         0.31             9.1
# 6063     red            8.5              0.44         0.50             1.9
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 1916      0.045                 54.0                 180.0  0.99580  3.08
# 947       0.039                 24.0                 147.0  0.99350  2.96
# 877       0.119                 33.0                 104.0  0.99210  3.19
# 2927      0.036                 45.0                 140.0  0.99216  2.98
# 6063      0.369                 15.0                  38.0  0.99634  3.01
#
#       sulphates  alcohol  quality
# 1916       0.42      9.2        5
# 947        0.36     10.0        5
# 877        0.38     10.2        6
# 2927       0.31     12.0        7
# 6063       1.10      9.4        5

# %%
data = data.astype(synthesized.dtypes)

# %%
test = data.astype(synthesized.dtypes)

# %% [markdown]
# # Visualization of original and synthetic data

# %%
synthesized.hist(figsize=(10,10))
None

# %%
data.hist(figsize=(10, 10))
None

# %% [markdown]
# # Tests to confirm the utility of synthetic data

# %%
from synthesized.testing.testing_environment import Testing, ColumnType
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor

# %%
testing = Testing(synthesizer, data, test, synthesized)

# %%
testing.show_corr_matrices()

# %%
testing.estimate_utility(classifier=DecisionTreeClassifier(), regressor=DecisionTreeRegressor())
# Out:
#                                    target_column               estimator  \
# 0                                        alcohol   DecisionTreeRegressor
# 1                alcohol (categorical reduction)  DecisionTreeClassifier
# 2                                      chlorides   DecisionTreeRegressor
# 3              chlorides (categorical reduction)  DecisionTreeClassifier
# 4                                    citric acid   DecisionTreeRegressor
# 5            citric acid (categorical reduction)  DecisionTreeClassifier
# 6                                        density   DecisionTreeRegressor
# 7                density (categorical reduction)  DecisionTreeClassifier
# 8                                  fixed acidity   DecisionTreeRegressor
# 9          fixed acidity (categorical reduction)  DecisionTreeClassifier
# 10                           free sulfur dioxide   DecisionTreeRegressor
# 11   free sulfur dioxide (categorical reduction)  DecisionTreeClassifier
# 12                                            pH   DecisionTreeRegressor
# 13                    pH (categorical reduction)  DecisionTreeClassifier
# 14                                       quality   DecisionTreeRegressor
# 15               quality (categorical reduction)  DecisionTreeClassifier
# 16                                residual sugar   DecisionTreeRegressor
# 17        residual sugar (categorical reduction)  DecisionTreeClassifier
# 18                                     sulphates   DecisionTreeRegressor
# 19             sulphates (categorical reduction)  DecisionTreeClassifier
# 20                          total sulfur dioxide   DecisionTreeRegressor
# 21  total sulfur dioxide (categorical reduction)  DecisionTreeClassifier
# 22                                       variant   DecisionTreeRegressor
# 23               variant (categorical reduction)  DecisionTreeClassifier
# 24                              volatile acidity   DecisionTreeRegressor
# 25      volatile acidity (categorical reduction)  DecisionTreeClassifier
#
#     dummy_original_score  original_score  synth_score  orig_error  \
# 0           0.000000e+00        0.999999     0.000000    0.000900
# 1           2.563017e-01        1.000000     0.151818    0.000000
# 2           2.135395e-08        1.000000     0.311740    0.000019
# 3           7.814124e-01        1.000000     0.844718    0.000000
# 4           0.000000e+00        1.000000     0.128934    0.000000
# 5           4.820089e-01        1.000000     0.432557    0.000000
# 6           0.000000e+00        0.993696     0.146652    0.000239
# 7           5.616702e-01        1.000000     0.616125    0.000000
# 8           0.000000e+00        0.997370     0.000000    0.067051
# 9           4.966327e-01        0.999808     0.207812    0.000192
# 10          1.529221e-08        1.000000     0.030678    0.000000
# 11          5.241485e-01        1.000000     0.582067    0.000000
# 12          0.000000e+00        1.000000     0.000000    0.000000
# 13          3.259573e-01        1.000000     0.142197    0.000000
# 14          0.000000e+00        1.000000     0.000000    0.000000
# 15          4.342890e-01        1.000000     0.267654    0.000000
# 16          0.000000e+00        0.999996     0.256433    0.009136
# 17          7.023283e-01        0.999615     0.554166    0.000385
# 18          0.000000e+00        1.000000     0.000000    0.000000
# 19          5.243410e-01        1.000000     0.451029    0.000000
# 20          3.718055e-10        0.999982     0.000000    0.238940
# 21          3.151818e-01        0.999808     0.245334    0.000192
# 22          0.000000e+00        0.998794     0.574060    0.014983
# 23          7.527420e-01        0.999615     0.929382    0.000385
# 24          0.000000e+00        1.000000     0.000000    0.000000
# 25          4.777756e-01        1.000000     0.386954    0.000000
#
#     synth_error  score_utility  error_utility
# 0      1.851439       0.000000       0.000486
# 1      0.846642       0.000000       0.000000
# 2      0.028179       0.311740       0.000658
# 3      0.153935       0.289613       0.000000
# 4      0.136005       0.128934       0.000000
# 5      0.564941       0.000000       0.000000
# 6      0.002709       0.147583       0.088093
# 7      0.446604       0.124232       0.000000
# 8      2.387876       0.000000       0.028080
# 9      0.785068       0.000000       0.000245
# 10    17.359165       0.030678       0.000000
# 11     0.414277       0.121715       0.000000
# 12     0.548728       0.000000       0.000000
# 13     0.851260       0.000000       0.000000
# 14     1.731606       0.000000       0.000000
# 15     0.746585       0.000000       0.000000
# 16     4.170151       0.256434       0.002191
# 17     0.440831       0.000000       0.000873
# 18     0.154841       0.000000       0.000000
# 19     0.573600       0.000000       0.000000
# 20    64.320247       0.000000       0.003715
# 21     0.745045       0.000000       0.000258
# 22     0.268978       0.574754       0.055703
# 23     0.073889       0.715511       0.005208
# 24     0.204105       0.000000       0.000000
# 25     0.620935       0.000000       0.000000

# %%
testing.compare_marginal_distributions(target_column='quality', conditional_column='density')
# Out:
#                                     density  quality EMD
# 0  [0.9871299862861633, 1.0000924915075302)     0.432112
# 1   [1.0000924915075302, 1.013054996728897)     0.252965
# 2    [1.013054996728897, 1.026017501950264)          inf
# 3   [1.026017501950264, 1.0389800071716309)          inf

# %%
testing.compare_marginal_distributions(target_column='quality', conditional_column='variant')
# Out:
#        variant  quality EMD
# 0  [0.0, 0.25)     0.455872
# 1  [0.25, 0.5)          inf
# 2  [0.5, 0.75)          inf
# 3  [0.75, 1.0)          inf

# %%
testing.compare_marginal_distributions(target_column='sulphates', conditional_column='chlorides', bins=10)
# Out:
#                                      chlorides  sulphates EMD
# 0  [0.008999999612569809, 0.06919999979436398)       0.019401
# 1   [0.06919999979436398, 0.12939999997615814)       0.022812
# 2    [0.12939999997615814, 0.1896000001579523)       0.158656
# 3    [0.1896000001579523, 0.24980000033974648)       0.237058
# 4   [0.24980000033974648, 0.31000000052154064)       0.243392
# 5    [0.31000000052154064, 0.3702000007033348)       0.309000
# 6      [0.3702000007033348, 0.430400000885129)            inf
# 7     [0.430400000885129, 0.49060000106692314)            inf
# 8    [0.49060000106692314, 0.5508000012487173)            inf
# 9     [0.5508000012487173, 0.6110000014305115)            inf

# %% [markdown]
# # Tests to confirm the security of original data

# %%
from synthesized.testing.linkage_attack import identify_attacks, Column, show_attacked_data, eradicate_attacks

# %% [markdown]
# ## Focus on a small chunk of original data for demo purposes

# %%
data_orig_reduced = data.head(30000)

# %% [markdown]
# ## Define schema for security checks
#
# Each attribute in a dataset has the following properties to be specified by the user
# 1. "key_attribute" - whether the attribute can be available to the attacker as background knowledge
# 2. "sensitive" - whether the attribute is SPI
# 3. "categorical" - wtether the attribute is a categorical variable

# %%
schema = {
    'type': Column(key_attribute=False, sensitive=True, categorical=True),
    'operation': Column(key_attribute=True, sensitive=True, categorical=True),
    'amount': Column(key_attribute=True, sensitive=True, categorical=False),
    'account_id': Column(key_attribute=False, sensitive=False, categorical=False),
}

# %% [markdown]
# ## Identify and demonstrate vulnerabilities in synthetic data

# %%
attacks = identify_attacks(data_orig_reduced, synthesized, schema)

# %%
len(attacks)
# Out:
# 1293

# %%
show_attacked_data(data_orig_reduced, synthesized, attacks[3], schema)
# Out:
# attribute under attack:  operation
#
# bacground knowledge:  amount
#
#
#  original df subset:
#           account_id  type  operation  amount
# 73484         171.0     0          3    30.0
# 120253        284.0     0          3    30.0
# 539749       1425.0     0          3    30.0
# 11690          26.0     0          3    30.0
# 911137       3166.0     0          3    30.0
# 764169       2339.0     0          3    30.0
# 242623        590.0     0          3    30.0
# 541120       1429.0     0          3    30.0
# 360068        898.0     0          3    30.0
# 391445        986.0     0          3    30.0
# 26105          59.0     0          3    30.0
# 878330       2967.0     0          3    30.0
# 1042390      4281.0     0          3    30.0
# 332440        823.0     0          3    30.0
# 120343        284.0     0          3    30.0
# 503325       1311.0     0          3    30.0
# 698310       2021.0     0          3    30.0
# 1003457      3865.0     0          3    30.0
# 169893        406.0     0          3    30.0
# 570227       1527.0     0          3    30.0
# 511381       1334.0     0          3    30.0
# 338903        840.0     0          3    30.0
# 751807       2275.0     0          3    30.0
# 850384       2798.0     0          3    30.0
# 188569        452.0     0          3    30.0
# 87055         204.0     0          3    30.0
# 245373        597.0     0          3    30.0
# 338925        840.0     0          3    30.0
# 529332       1391.0     0          3    30.0
# 587001       1585.0     0          3    30.0
# ...             ...   ...        ...     ...
# 1045510      4322.0     0          3    30.0
# 477419       1232.0     0          3    30.0
# 390060        983.0     0          3    30.0
# 50438         117.0     0          3    30.0
# 652222       1828.0     0          3    30.0
# 28663          65.0     0          3    30.0
# 305910        752.0     0          3    30.0
# 868988       2910.0     0          3    30.0
# 634293       1755.0     0          3    30.0
# 783822       2443.0     0          3    30.0
# 169832        406.0     0          3    30.0
# 208838        506.0     0          3    30.0
# 691481       1989.0     0          3    30.0
# 137650        328.0     0          3    30.0
# 716011       2099.0     0          3    30.0
# 868903       2910.0     0          3    30.0
# 633812       1754.0     0          3    30.0
# 600628       1633.0     0          3    30.0
# 967472       3562.0     0          3    30.0
# 762512       2328.0     0          3    30.0
# 137070        327.0     0          3    30.0
# 11676          26.0     0          3    30.0
# 500709       1303.0     0          3    30.0
# 1018802      4013.0     0          3    30.0
# 636759       1764.0     0          3    30.0
# 11945          26.0     0          3    30.0
# 960046       3505.0     0          3    30.0
# 911036       3166.0     0          3    30.0
# 634389       1755.0     0          3    30.0
# 1045524      4322.0     0          3    30.0
#
# [309 rows x 4 columns]
#
#
#  synthetic df subset:
#        account_id  type  operation     amount
# 2015          16     0          3  30.036186
# 2590          16     0          3  29.563486
# 5297          16     0          3  30.216667
# 7093          16     0          3  29.944948
# 7272          16     0          3  29.475159
# 7883          16     0          3  29.633980

# %% [markdown]
# ## Clear the synthetic dataset from vulnerabilities

# %%
cleared_df = eradicate_attacks(data_orig_reduced, synthesized, attacks, schema)
# Out:
# remaining attacks :  1293
# /Users/denisborovikov/IdeaProjects/synthesized/synthesized/testing/testing_environment.py:236: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /Users/denisborovikov/IdeaProjects/synthesized/synthesized/testing/testing_environment.py:235: RuntimeWarning:
#
# invalid value encountered in true_divide
# remaining attacks :  67
# remaining attacks :  3

# %% [markdown]
# ## Demonstrate the security of synthetic data

# %%
new_attacks = identify_attacks(data_orig_reduced, cleared_df, schema)

# %%
len(new_attacks)
# Out:
# 0

# %% [markdown]
# ## Demonstrate the utility of synthetic data cleared from all vulnerabilities

# %%
testing = Testing(data, cleared_df, synthesized, schema={
    'type': ColumnType.CATEGORICAL,
    'operation': ColumnType.CATEGORICAL,
    'amount': ColumnType.CONTINUOUS,
})

# %%
testing.estimate_utility(classifier=DecisionTreeClassifier(), regressor=DecisionTreeRegressor())
# Out:
#                     target_column               estimator  \
# 0                          amount   DecisionTreeRegressor
# 1  amount (categorical reduction)  DecisionTreeClassifier
# 2                       operation  DecisionTreeClassifier
# 3                            type  DecisionTreeClassifier
#
#    dummy_original_score  original_score  synth_score    orig_error  \
# 0              0.000000        0.000000     0.092009  14303.090350
# 1              0.105607        0.105607     0.511185      0.894393
# 2              0.017723        0.130763     0.401553      0.869237
# 3              0.661488        0.355649     0.371179      0.644351
#
#    synth_error  score_utility  error_utility
# 0  8334.100440       0.000000       1.716213
# 1     0.488815       0.000000       1.829716
# 2     0.598447       3.395535       1.452489
# 3     0.628649            NaN       1.024977

# %% [markdown]
# ## Demonstrate the synthetic dataset to be released to the user

# %%
synthesized
# Out:
#       account_id  type  operation        amount
# 0            314     0          0   3482.375244
# 1           1068     0          3  12373.549805
# 2            629     1          0   7045.999023
# 3             15     0          3      9.458170
# 4            410     1          0   4617.419434
# 5            328     0          0   3623.130127
# 6             15     0          3      9.458170
# 7            477     0          3   5429.196289
# 8             15     0          3      9.458170
# 9           1435     0          3  16667.007812
# 10           291     0          3   3226.868408
# 11            37     0          3    272.909180
# 12           954     0          3  11032.276367
# 13            15     0          3      9.458170
# 14           690     1          0   7758.718750
# 15            15     0          3      9.458170
# 16           209     0          3   2274.830078
# 17           281     0          0   3086.843018
# 18           281     0          3   3151.075684
# 19           347     0          3   3915.509766
# 20            78     0          3    772.415955
# 21          1624     0          3  18920.292969
# 22           735     1          0   8359.877930
# 23            15     0          3      9.458170
# 24           617     0          3   7056.615234
# 25           491     0          3   5558.554688
# 26           127     0          3   1337.882446
# 27            15     0          3      9.458170
# 28           135     0          0   1380.764038
# 29          1147     1          1  13228.378906
# ...          ...   ...        ...           ...
# 9970         571     1          0   6460.631348
# 9971         479     0          3   5447.020508
# 9972        1118     1          1  12895.362305
# 9973        1989     1          3  23132.257812
# 9974          22     0          3     92.893478
# 9975         304     1          0   3316.167725
# 9976         331     0          3   3717.486816
# 9977         388     0          3   4411.781250
# 9978          15     0          3      9.458170
# 9979         480     0          3   5432.807617
# 9980         236     0          3   2612.067383
# 9981          19     0          3     72.394928
# 9982        1096     1          1  12623.454102
# 9983          15     0          3     10.565173
# 9984        1167     0          3  13519.684570
# 9985          17     0          3     36.543472
# 9986          62     0          0    535.473633
# 9987         192     0          0   2057.956299
# 9988          37     0          3    289.964142
# 9989          15     0          3     15.876358
# 9990          15     0          3     10.097777
# 9991         377     0          3   4230.219727
# 9992          15     0          3      9.458170
# 9993        1042     0          3  12042.768555
# 9994        2692     1          1  31362.855469
# 9995         278     0          3   3134.080322
# 9996         376     0          3   4226.219238
# 9997         870     1          2   9964.766602
# 9998         553     0          3   6295.781738
# 9999          15     0          3      9.458170
#
# [10000 rows x 4 columns]
