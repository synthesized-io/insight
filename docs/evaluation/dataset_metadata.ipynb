# %%
import os
import json
from itertools import chain

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

from synthesized.common import ValueFactory

# %%
configs = json.load(open('../configs/evaluation/dataset_evaluation.json', 'r'))['instances']
configs.update(json.load(open('../configs/hyperparam/0_master.json', 'r'))['instances'])


records = []
for dataset, config in configs.items():
    if dataset in ['arx', 'housing_prices', 'james', 'vitor', 'uci_creditcard_default',
                  'sweden_motor_insurance', 'sales_pipeline', 'fraud_detection']:
        current = 'evaluator'
    else:
        current = 'template'
        
    if dataset in ['credit_scoring', 'claim_prediction', 'default_on_loan_payment',
                   'segmentation_analysis', 'sales_pipeline', 'insurance_quote_conversion',
                   'ibm_watson_marketing_customer_value_data', 'bank_marketing_dataset',
                   'bank_loan_status', 'medical_appointment_no_shows', 'diabetes_dataset',
                   'bank_churn_modelling', 'telecom_customer_churn', 
                   'epileptic_seizure_recognition_data_set', 'occupancy_detection', 
                   'atlas_higgs_boson_detection_data_set', 'james', 'arx', 
                   'uci_creditcard_default', 'vitor']:
        utility = 'bool'
    elif dataset in ['housing_prices', 'business_property_insurance_risk', 
                     'vehicle_insurance_claim_prediction', 
                     'prediction_of_electric_motor_temperature', 'air_quality_data_set',
                     'sweden_motor_insurance']:
        utility = 'continuous'
    elif dataset in ['nursery_school_application_decision', 'student_information']:
        utility = 'categorical'
    else:
        utility = 'N/A'
    
    name = '../'+config['data']
    data = pd.read_csv(open(name, 'r'))
    if 'Unnamed: 0' in data.columns:
        del data['Unnamed: 0']

    spec = [
        {k: j for k,j in chain(v.specification().items(),[('class_name', v.__class__.__name__)])} 
        for v in ValueFactory(data).get_values()
    ]
    for s in spec:
        if 'categories' in s:
            s['categories'] = '['+', '.join([str(o) for o in s['categories']])+']'
    
    for n, v in enumerate(ValueFactory(data).get_values()):
        if hasattr(v, 'day'):
            spec[n]['embedding_size'] = v.learned_input_size()
        if v.__class__.__name__ == 'NanValue':
            spec.append({'class_name': v.value.__class__.__name__,
                        'name': v.name+'_value'})
            

    # print(json.dumps(spec, cls=CustomJSONEncoder, indent=2))
    records.append((dataset, '_Rows', len(data)))
    records.append((dataset, '_utility', utility))
    records.extend([(dataset, a, b) 
                    for a, b in pd.DataFrame.from_records(spec).filter(regex='|'.join(['class_name', 'name'])).groupby('class_name').count().to_records()])
    
metadf = pd.DataFrame.from_records(records, columns=['dataset', 'value', 'name']).pivot(index='dataset',columns='value', values=['name'])

# %%
metadf['name']
# Out:
# value                                              CategoricalValue  \
# dataset
# air_quality_data_set                                            NaN
# arx                                                               7
# atlas_higgs_boson_detection_data_set                              2
# bank_churn_modelling                                              7
# bank_loan_status                                                 11
# bank_marketing_dataset                                           10
# big_cities_health_coalition_dataset                               4
# business_property_insurance_risk                                  9
# claim_prediction                                                  5
# credit_scoring                                                    6
# default_on_loan_payment                                          10
# diabetes_dataset                                                 38
# epileptic_seizure_recognition_data_set                            3
# fraud_detection                                                   4
# housing_prices                                                    4
# ibm_watson_marketing_customer_value_data                         16
# insurance_quote_conversion                                       49
# james                                                             7
# medical_appointment_no_shows                                      9
# medicare_provider_utilization_and_payment_dataset                 5
# nursery_school_application_decision                               9
# occupancy_detection                                               1
# prediction_of_electric_motor_temperature                          1
# pricing_of_goods_at_different_locations                           2
# sales_pipeline                                                   11
# segmentation_analysis                                             9
# student_information                                              10
# sweden_motor_insurance                                            4
# synthetic_fraud_data_from_a_financial_payment_s...                4
# telecom_customer_churn                                           17
# uci_creditcard_default                                           10
# vehicle_insurance_claim_prediction                               11
# vitor                                                            22
#
# value                                              ConstantValue  \
# dataset
# air_quality_data_set                                         NaN
# arx                                                          NaN
# atlas_higgs_boson_detection_data_set                         NaN
# bank_churn_modelling                                         NaN
# bank_loan_status                                             NaN
# bank_marketing_dataset                                       NaN
# big_cities_health_coalition_dataset                          NaN
# business_property_insurance_risk                             NaN
# claim_prediction                                             NaN
# credit_scoring                                               NaN
# default_on_loan_payment                                      NaN
# diabetes_dataset                                               2
# epileptic_seizure_recognition_data_set                       NaN
# fraud_detection                                                2
# housing_prices                                                 1
# ibm_watson_marketing_customer_value_data                     NaN
# insurance_quote_conversion                                     1
# james                                                        NaN
# medical_appointment_no_shows                                 NaN
# medicare_provider_utilization_and_payment_dataset              1
# nursery_school_application_decision                          NaN
# occupancy_detection                                          NaN
# prediction_of_electric_motor_temperature                     NaN
# pricing_of_goods_at_different_locations                        3
# sales_pipeline                                               NaN
# segmentation_analysis                                        NaN
# student_information                                          NaN
# sweden_motor_insurance                                       NaN
# synthetic_fraud_data_from_a_financial_payment_s...           NaN
# telecom_customer_churn                                       NaN
# uci_creditcard_default                                       NaN
# vehicle_insurance_claim_prediction                           NaN
# vitor                                                        NaN
#
# value                                              ContinuousValue DateValue  \
# dataset
# air_quality_data_set                                            13         1
# arx                                                              2       NaN
# atlas_higgs_boson_detection_data_set                            31       NaN
# bank_churn_modelling                                             6       NaN
# bank_loan_status                                                 6       NaN
# bank_marketing_dataset                                           7       NaN
# big_cities_health_coalition_dataset                              5       NaN
# business_property_insurance_risk                                26       NaN
# claim_prediction                                                 3       NaN
# credit_scoring                                                   5       NaN
# default_on_loan_payment                                         15       NaN
# diabetes_dataset                                                 9       NaN
# epileptic_seizure_recognition_data_set                         178       NaN
# fraud_detection                                                  2       NaN
# housing_prices                                                   1         1
# ibm_watson_marketing_customer_value_data                         6         1
# insurance_quote_conversion                                       6         1
# james                                                            4       NaN
# medical_appointment_no_shows                                     3         1
# medicare_provider_utilization_and_payment_dataset               10       NaN
# nursery_school_application_decision                            NaN       NaN
# occupancy_detection                                              5         1
# prediction_of_electric_motor_temperature                        12       NaN
# pricing_of_goods_at_different_locations                          5       NaN
# sales_pipeline                                                   8       NaN
# segmentation_analysis                                            5       NaN
# student_information                                              2       NaN
# sweden_motor_insurance                                           3       NaN
# synthetic_fraud_data_from_a_financial_payment_s...               2       NaN
# telecom_customer_churn                                           3       NaN
# uci_creditcard_default                                          15       NaN
# vehicle_insurance_claim_prediction                              12       NaN
# vitor                                                            1         1
#
# value                                              NanValue SamplingValue  \
# dataset
# air_quality_data_set                                    NaN             1
# arx                                                     NaN             1
# atlas_higgs_boson_detection_data_set                    NaN           NaN
# bank_churn_modelling                                    NaN             1
# bank_loan_status                                          6             2
# bank_marketing_dataset                                  NaN           NaN
# big_cities_health_coalition_dataset                       5             6
# business_property_insurance_risk                         20             1
# claim_prediction                                        NaN           NaN
# credit_scoring                                            1           NaN
# default_on_loan_payment                                 NaN           NaN
# diabetes_dataset                                          3             1
# epileptic_seizure_recognition_data_set                  NaN             1
# fraud_detection                                         NaN             2
# housing_prices                                          NaN             3
# ibm_watson_marketing_customer_value_data                NaN             1
# insurance_quote_conversion                              NaN           NaN
# james                                                     1           NaN
# medical_appointment_no_shows                            NaN             1
# medicare_provider_utilization_and_payment_dataset         1            10
# nursery_school_application_decision                     NaN           NaN
# occupancy_detection                                     NaN           NaN
# prediction_of_electric_motor_temperature                NaN           NaN
# pricing_of_goods_at_different_locations                   1             3
# sales_pipeline                                          NaN           NaN
# segmentation_analysis                                   NaN             1
# student_information                                     NaN           NaN
# sweden_motor_insurance                                  NaN           NaN
# synthetic_fraud_data_from_a_financial_payment_s...      NaN             2
# telecom_customer_churn                                    1             1
# uci_creditcard_default                                  NaN           NaN
# vehicle_insurance_claim_prediction                      NaN             3
# vitor                                                   NaN             3
#
# value                                                _Rows     _utility
# dataset
# air_quality_data_set                                  9357   continuous
# arx                                                  30162         bool
# atlas_higgs_boson_detection_data_set                100000         bool
# bank_churn_modelling                                 10000         bool
# bank_loan_status                                    110514         bool
# bank_marketing_dataset                               11162         bool
# big_cities_health_coalition_dataset                  34492          N/A
# business_property_insurance_risk                    105450   continuous
# claim_prediction                                      1338         bool
# credit_scoring                                      150000         bool
# default_on_loan_payment                              30000         bool
# diabetes_dataset                                    101766         bool
# epileptic_seizure_recognition_data_set               11500         bool
# fraud_detection                                     594643          N/A
# housing_prices                                      134000   continuous
# ibm_watson_marketing_customer_value_data              9134         bool
# insurance_quote_conversion                           67504         bool
# james                                               150000         bool
# medical_appointment_no_shows                        110527         bool
# medicare_provider_utilization_and_payment_dataset    10000          N/A
# nursery_school_application_decision                  12960  categorical
# occupancy_detection                                  20560         bool
# prediction_of_electric_motor_temperature            100000   continuous
# pricing_of_goods_at_different_locations              10000          N/A
# sales_pipeline                                       78025         bool
# segmentation_analysis                                32561         bool
# student_information                                  32593  categorical
# sweden_motor_insurance                                2182   continuous
# synthetic_fraud_data_from_a_financial_payment_s...  594643          N/A
# telecom_customer_churn                                7043         bool
# uci_creditcard_default                               30000         bool
# vehicle_insurance_claim_prediction                  209240   continuous
# vitor                                                 1258         bool

# %%
metadf['name'].filter(regex="|".join(["housing_prices", "occupancy_detection", "prediction_of_electric_motor_temperature",
"atlas_higgs_boson_detection_data_set", "vehicle_insurance_claim_prediction",
"medical_appointment_no_shows", "james", "business_property_insurance_risk", "telecom_customer_churn"]), axis=0)
# metadf['name'].filter(regex="|".join(["arx", "housing_prices", "segmentation_analysis",
# "sales_pipeline", "sweden_motor_insurance", "vehicle_insurance_claim_prediction",
# "fraud_detection", "james", "uci_creditcard_default", "vitor"]), axis=0)
# Out:
# value                                    CategoricalValue ConstantValue  \
# dataset
# atlas_higgs_boson_detection_data_set                    2           NaN
# business_property_insurance_risk                        9           NaN
# housing_prices                                          4             1
# james                                                   7           NaN
# medical_appointment_no_shows                            9           NaN
# occupancy_detection                                     1           NaN
# prediction_of_electric_motor_temperature                1           NaN
# telecom_customer_churn                                 17           NaN
# vehicle_insurance_claim_prediction                     11           NaN
#
# value                                    ContinuousValue DateValue NanValue  \
# dataset
# atlas_higgs_boson_detection_data_set                  31       NaN      NaN
# business_property_insurance_risk                      26       NaN       20
# housing_prices                                         1         1      NaN
# james                                                  4       NaN        1
# medical_appointment_no_shows                           3         1      NaN
# occupancy_detection                                    5         1      NaN
# prediction_of_electric_motor_temperature              12       NaN      NaN
# telecom_customer_churn                                 3       NaN        1
# vehicle_insurance_claim_prediction                    12       NaN      NaN
#
# value                                    SamplingValue   _Rows    _utility
# dataset
# atlas_higgs_boson_detection_data_set               NaN  100000        bool
# business_property_insurance_risk                     1  105450  continuous
# housing_prices                                       3  134000  continuous
# james                                              NaN  150000        bool
# medical_appointment_no_shows                         1  110527        bool
# occupancy_detection                                NaN   20560        bool
# prediction_of_electric_motor_temperature           NaN  100000  continuous
# telecom_customer_churn                               1    7043        bool
# vehicle_insurance_claim_prediction                   3  209240  continuous

# %%
dfdf = metadf['name'].drop(labels=[
    'epileptic_seizure_recognition_data_set',
    'insurance_quote_conversion',
    'diabetes_dataset'
], axis=0)
fig = plt.figure(figsize=(12,8))
ax = fig.gca()
p1=sns.scatterplot(
    data=dfdf, x="ContinuousValue", y="CategoricalValue", 
    marker="o", size_norm=LogNorm(), hue='_utility',
    size="_Rows", sizes=(8,180), axes=ax)
 
# add annotations one by one with a loop
labelled = []
for line in range(0,dfdf.shape[0]):
    loc = (dfdf.ContinuousValue[line], dfdf.CategoricalValue[line])
    np.random.seed(int(loc[0] if not np.isnan(loc[0]) else 0))
    if loc not in labelled:
        labelled.append(loc)
        p1.text(dfdf.ContinuousValue[line]+0.2, 
                 dfdf.CategoricalValue[line]+0.2+np.random.uniform(-0.3,0.3), 
                 dfdf.index[line], horizontalalignment='left', 
                 size='small', color='black', weight='normal')
    else:
        p1.text(dfdf.ContinuousValue[line]+0.2, 
                 dfdf.CategoricalValue[line]-0.2+np.random.uniform(-0.3,0.3), 
                 dfdf.index[line], horizontalalignment='left', 
                 size='small', color='black', weight='normal')
# Out:
# 2020-02-03 17:00:44,699 :: WARNING :: posx and posy should be finite values
# 2020-02-03 17:00:44,745 :: WARNING :: posx and posy should be finite values
# 2020-02-03 17:00:44,820 :: WARNING :: posx and posy should be finite values
# 2020-02-03 17:00:44,849 :: WARNING :: posx and posy should be finite values
# 2020-02-03 17:00:45,106 :: WARNING :: posx and posy should be finite values
# 2020-02-03 17:00:45,134 :: WARNING :: posx and posy should be finite values

# %%
"housing_prices", "occupancy_detection", "prediction_of_electric_motor_temperature",
"atlas_higgs_boson_detection_data_set", "vehicle_insurance_claim_predicion",
"student_information", "james", "business_property_insurance_risk"

# %%
df = pd.DataFrame.from_records(
    json.load(
    open('/Users/simonhkswan/PycharmProjects/synthesized/logs/hparams/hparams.json', 'r')),
    columns=['dataset', 'capacity', 'ks', 'ks_max', 'cor', 
             'cor_max', 'emd', 'emd_max', 'time', 'cont', 'cat']
)
df = df.melt(
    id_vars=['dataset', 'capacity', 'time', 'cont', 'cat'],
    value_vars=['ks', 'ks_max', 'cor', 
                'cor_max', 'emd', 'emd_max'],
    var_name='metric',
    value_name='value',
)

# %%
sns.catplot(data=df, x='capacity', y='value', hue='metric', col='dataset', palette='Paired')
